# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('/home/gauravk/Documents/DataScience/Datasets/Ongoing Competitions/Funding Successful Projects/')

# %% [markdown]
# Ideas
# - convert epochs to datetime to extract the months and days and possibly week features as well from the data
# - state_changed at is greater than deadline, always ?
# - disable communication? - currency too
# - first iteration, I could use goal , times launched, and deadline,  country
#
# - desc and keywords have to be categorized into usable data
# - effect of classes on svc.

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train  = train.dropna()
print(train.shape)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder().fit(test.currency)
train.currency = le.transform(train.currency)
test.currency = le.transform(test.currency)

le2 = LabelEncoder().fit(test.country)
train.country = le2.transform(train.country)
test.country = le2.transform(test.country)

test.columns
first_attempt = ['goal', 'country', 'currency', 'deadline',
       'state_changed_at', 'created_at', 'launched_at','final_status']
train = train[first_attempt] # disable_communication
test = test[first_attempt[:-1]]
# scaling the data

from sklearn.preprocessing import  MinMaxScaler
toScale = ['goal', 'country', 'currency', 'deadline', 'state_changed_at', 'created_at', 'launched_at']
ss = MinMaxScaler().fit(train[toScale])
train_scaled = pd.DataFrame(ss.transform(train[toScale]))
test_scaled = pd.DataFrame(ss.transform(test[toScale]))
train_scaled.columns = toScale
test_scaled.columns = toScale
train_scaled['disable_communication'] = train['disable_communication']
train_scaled['final_status'] = train['final_status']
test_scaled['disable_communication'] = test['disable_communication']
print(train.columns)
print(train_scaled.columns)
print(test.columns)
print(test_scaled.columns)


from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train_scaled[train_scaled.columns[:-1]], train_scaled[train_scaled.columns[-1]], test_size = .25, random_state =42)
# Out:
# (108121, 14)
# Index(['goal', 'country', 'currency', 'deadline', 'disable_communication',
#        'state_changed_at', 'created_at', 'launched_at', 'final_status'],
#       dtype='object')
# Index(['goal', 'country', 'currency', 'deadline', 'state_changed_at',
#        'created_at', 'launched_at', 'disable_communication', 'final_status'],
#       dtype='object')
# Index(['goal', 'country', 'currency', 'deadline', 'disable_communication',
#        'state_changed_at', 'created_at', 'launched_at'],
#       dtype='object')
# Index(['goal', 'country', 'currency', 'deadline', 'state_changed_at',
#        'created_at', 'launched_at', 'disable_communication'],
#       dtype='object')

# %%
# from sklearn.ensemble import  RandomForestClassifier
# lr = RandomForestClassifier()
# lr.fit(X_train, y_train)
# y_pred = lr.predict(X_test)
# print(accuracy_score(y_train, lr.predict(X_train)))
# print(accuracy_score(y_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-dffb51413a9f> in <module>()
#       1 from sklearn.ensemble import  RandomForestClassifier
#       2 lr = RandomForestClassifier()
# ----> 3 lr.fit(X_train, y_train)
#       4 y_pred = lr.predict(X_test)
#       5 print(accuracy_score(y_train, lr.predict(X_train)))
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if issparse(X):
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
from sklearn.svm import SVC
lr = SVC()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.svm import LinearSVC
lr = LinearSVC()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_pred, y_test))

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-69a347ea9042> in <module>()
#       1 from sklearn.linear_model import LogisticRegression
#       2 lr = LogisticRegression()
# ----> 3 lr.fit(X_train, y_train)
#       4 y_pred = lr.predict(X_test)
#       5 print(accuracy_score(y_train, lr.predict(X_train)))
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_train
# Out:
#                 goal   country  currency  deadline  state_changed_at  \
# 10660   9.999900e-06  1.000000  1.000000  0.389743          0.389743
# 76597   2.999990e-05  1.000000  1.000000  0.893833          0.893833
# 84510   8.887990e-05  1.000000  1.000000  0.920883          0.920883
# 50301   3.499990e-05  0.105263  0.083333  0.757707          0.757707
# 80328   1.199990e-05  1.000000  1.000000  0.906747          0.906747
# 54886   6.999900e-06  1.000000  1.000000  0.800847          0.800847
# 76820   4.999990e-05  1.000000  1.000000  0.894590          0.894590
# 103694  2.999999e-04  0.105263  0.083333  0.986528          0.986528
# 860     4.999990e-05  1.000000  1.000000  0.160108          0.160112
# 15795   9.999990e-05  1.000000  1.000000  0.458066          0.458066
#
#         created_at  launched_at disable_communication
# 10660     0.380955     0.379460                 False
# 76597     0.883141     0.881882                 False
# 84510     0.840006     0.896276                 False
# 50301     0.744960     0.751362                 False
# 80328     0.895734     0.895657                 False
# 41195     0.659008     0.664879                 False
# 53610     0.770483     0.772329                 False
# 921       0.142799     0.145371                 False
# 73729     0.874541     0.873066                 False
# 19082     0.467216     0.483609                 False
# 72689     0.842001     0.866038                 False
# 19071     0.473617     0.476820                 False
# 97540     0.953411     0.958745                 False
# 13959     0.418765     0.426976                 False
# 21371     0.493428     0.494075                 False
# 21587     0.471815     0.489608                 False
# 47321     0.672254     0.722403                 False
# 64040     0.855538     0.855679                 False
# 38214     0.605406     0.637901                 False
# 70928     0.877175     0.875552                 False
# 47906     0.709331     0.727770                 False
# 96829     0.946178     0.944474                 False
# 94028     0.950191     0.948490                  True
# 96413     0.960399     0.958702                 False
# 73941     0.871548     0.873849                 False
# 10927     0.374948     0.382973                 False
# 58669     0.783144     0.818550                 False
# 72316     0.870372     0.869153                 False
# 20657     0.481615     0.489072                 False
# 85173     0.868826     0.901754                 False
# ...            ...          ...                   ...
# 106970    0.978306     0.976634                 False
# 93016     0.929802     0.947121                 False
# 71932     0.861304     0.868260                 False
# 28693     0.493030     0.554003                 False
# 85305     0.915046     0.920865                 False
# 53707     0.765120     0.779988                 False
# 83104     0.914009     0.912337                 False
# 104724    0.979446     0.978434                 False
# 103355    0.963171     0.973698                 False
# 5311      0.284972     0.285858                 False
# 67969     0.858965     0.857965                 False
# 64925     0.851788     0.850149                 False
# 62955     0.835860     0.841005                 False
# 59735     0.789392     0.821043                 False
# 769       0.117123     0.116121                 False
# 64820     0.772804     0.849729                 False
# 67221     0.857284     0.856484                 False
# 41090     0.667774     0.668512                 False
# 16023     0.445542     0.448222                 False
# 60263     0.819648     0.827455                 False
# 44131     0.692283     0.700187                 False
# 87498     0.915436     0.920329                 False
# 37194     0.626272     0.638378                 False
# 82386     0.889223     0.902301                 False
# 6265      0.320900     0.319958                 False
# 54886     0.778609     0.780958                 False
# 76820     0.871821     0.883537                 False
# 103694    0.961680     0.961858                 False
# 860       0.133187     0.135003                 False
# 15795     0.449114     0.452130                 False
#
# [81090 rows x 8 columns]

# %%
a = np.array([2, 3])

# %%
from sklearn.neighbors import KNeighborsClassifier
lr = KNeighborsClassifier(n_neighbors=10)
# %timeit lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_train, lr.predict(X_train)))
print(accuracy_score(y_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-56302cc2031f> in <module>()
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 lr = KNeighborsClassifier(n_neighbors=10)
# ----> 3 get_ipython().magic('timeit lr.fit(X_train, y_train)')
#       4 y_pred = lr.predict(X_test)
#       5 print(accuracy_score(y_train, lr.predict(X_train)))
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-58> in timeit(self, line, cell)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1047             number = 1
#    1048             for _ in range(1, 10):
# -> 1049                 time_number = timer.timeit(number)
#    1050                 worst_tuning = max(worst_tuning, time_number / number)
#    1051                 if time_number >= 0.2:
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/IPython/core/magics/execution.py in timeit(self, number)
#     137         gc.disable()
#     138         try:
# --> 139             timing = self.inner(it, self.timer)
#     140         finally:
#     141             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# --> 761             X, y = check_X_y(X, y, "csr", multi_output=True)
#     762
#     763         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     519     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     520                     ensure_2d, allow_nd, ensure_min_samples,
# --> 521                     ensure_min_features, warn_on_dtype, estimator)
#     522     if multi_output:
#     523         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     405                              % (array.ndim, estimator_name))
#     406         if force_all_finite:
# --> 407             _assert_all_finite(array)
#     408
#     409     shape_repr = _shape_repr(array.shape)
#
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X)
#      56             and not np.isfinite(X).all()):
#      57         raise ValueError("Input contains NaN, infinity"
# ---> 58                          " or a value too large for %r." % X.dtype)
#      59
#      60
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
X_train.
