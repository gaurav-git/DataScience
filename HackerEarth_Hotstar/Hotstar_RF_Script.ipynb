# %%
import os
os.chdir("/home/gauravk/Documents/DataScience/Datasets/Ongoing Competitions/Predict the Segment/")

# %%
import numpy as np
import pandas as pd
import re

# %%
train_data = pd.read_json('train_data.json',orient="index")
test_data = pd.read_json('test_data.json',orient='index')

# %%
train_data.reset_index(inplace=True)

# %%
train_data
# Out:
#                index                                             cities  \
# 0            train-1                          gurgaon:55494,delhi:31892
# 1           train-10                  delhi:5862,nagar:8916,mumbai:1593
# 2          train-100                                   navi mumbai:4142
# 3         train-1000       new delhi:4131,chennai:2878,navi mumbai:1339
# 4        train-10000                          gurgaon:6077,chennai:4055
# 5       train-100000  hyderabad:998,bangalore:2748,gulbarga:43317,be...
# 6       train-100001                                  navi mumbai:10155
# 7       train-100002                       delhi:1571,navi mumbai:12729
# 8       train-100003                                         delhi:1318
# 9       train-100004             chandigarh:2214,delhi:3829,mumbai:9465
# 10      train-100005                                         delhi:5597
# 11      train-100006                                           dhaka:21
# 12      train-100007          gurgaon:3703,bangalore:6283,mumbai:132815
# 13      train-100008                                       jakarta:9428
# 14      train-100009                                     navi mumbai:53
# 15       train-10001                     gurgaon:4076,delhi:0,nagari:23
# 16      train-100010                             dhaka:4613,gazipur:317
# 17      train-100011                                         gurgaon:20
# 18      train-100012  jaipur:3616,bangalore:24234,delhi:5848,mumbai:692
# 19      train-100013                           chennai:24064,delhi:3419
# 20      train-100014                                  navi mumbai:18320
# 21      train-100015            gurgaon:6264,chennai:53769,mumbai:18429
# 22      train-100016                                        bhopal:1188
# 23      train-100017                                         delhi:2745
# 24      train-100018                                           delhi:28
# 25      train-100019                                    bangalore:10618
# 26       train-10002                                   navi mumbai:3263
# 27      train-100020  gurgaon:1560,chennai:7887,noida:1352,mumbai:15...
# 28      train-100021                                   navi mumbai:3902
# 29      train-100022                                          delhi:641
# ...              ...                                                ...
# 199970   train-99972                                        jalandhar:1
# 199971   train-99973                                       mumbai:13595
# 199972   train-99974              bangalore:6043,delhi:9578,mumbai:3811
# 199973   train-99975                          chandigarh:358,delhi:4870
# 199974   train-99976                          delhi:1149,ludhiana:20415
# 199975   train-99977                         dhaka:174485,Unknown:46106
# 199976   train-99978                                        mumbai:1309
# 199977   train-99979                                    chandigarh:1085
# 199978    train-9998                                     prabhadevi:108
# 199979   train-99980                         gurgaon:22653,mumbai:44208
# 199980   train-99981  hyderabad:8118,navi mumbai:11320,Unknown:0,vad...
# 199981   train-99982                            gurgaon:1319,mumbai:127
# 199982   train-99983                 pune:62,delhi:185,navi mumbai:5957
# 199983   train-99984                      hyderabad:1300,bangalore:8950
# 199984   train-99985                                       kolkata:4083
# 199985   train-99986                          gurgaon:1826,chennai:8179
# 199986   train-99987                    bangalore:7226,navi mumbai:9362
# 199987   train-99988                          navi mumbai:17,mumbai:520
# 199988   train-99989          new delhi:35334,bangalore:1157,delhi:3317
# 199989    train-9999                                        mumbai:2267
# 199990   train-99990                                    raghogarh:12856
# 199991   train-99991                       karachi:42761,Unknown:143302
# 199992   train-99992                                        thane:27012
# 199993   train-99993                                         delhi:3521
# 199994   train-99994  hyderabad:41901,bangalore:9124,chennai:105897,...
# 199995   train-99995                                       chennai:3901
# 199996   train-99996                                       mumbai:47741
# 199997   train-99997                                   navi mumbai:1939
# 199998   train-99998                           Unknown:16904,delhi:9288
# 199999   train-99999     kolkata:26,bangalore:2308,delhi:898,mumbai:828
#
#                                                       dow  \
# 0       1:3412,3:15878,2:1737,5:10975,4:20974,7:17820,...
# 1           1:5745,3:3025,2:3346,5:123,4:3007,7:1108,6:10
# 2                                                  3:4142
# 3                          1:658,3:5867,5:413,4:1339,7:71
# 4                       1:1641,2:480,4:1445,7:1663,6:4900
# 5       1:6707,3:1948,2:3574,5:8525,4:18938,7:8295,6:7344
# 6                             1:1575,3:5330,2:1242,4:2007
# 7                        1:333,2:2233,5:739,4:268,7:10727
# 8                                       2:34,5:1074,7:210
# 9                                     5:14,4:14292,7:1201
# 10                                                 7:5597
# 11                                                   2:21
# 12      1:27096,3:29521,2:19751,5:32613,4:14633,7:20,6...
# 13                                    3:187,2:3999,7:5242
# 14                                                   3:53
# 15                                 1:3582,3:78,2:363,7:74
# 16             1:971,3:448,2:905,5:1109,4:1159,7:25,6:312
# 17                                                   2:20
# 18       1:775,3:5408,2:4313,5:7915,4:10619,7:3528,6:1825
# 19                     1:20295,3:144,2:4055,5:1359,7:1629
# 20              1:3187,3:1294,2:3711,5:6913,4:2119,6:1096
# 21      1:32082,3:4034,2:26096,5:1738,4:5976,7:3639,6:...
# 22                                      1:285,4:710,7:192
# 23                                           5:2054,4:689
# 24                                                   2:28
# 25                                    1:4101,7:6022,6:495
# 26                                             1:2,7:3261
# 27      1:2456,3:3289,2:7700,5:8436,4:11843,7:13631,6:...
# 28                                                 4:3902
# 29                                                  6:641
# ...                                                   ...
# 199970                                                1:1
# 199971                                      4:8602,7:4992
# 199972       1:2066,3:2226,2:359,5:621,4:4127,7:10023,6:9
# 199973                     3:2435,2:74,5:1685,4:838,6:195
# 199974       1:2366,3:208,2:4687,5:148,4:7977,7:6109,6:67
# 199975  1:17069,3:28708,2:20497,5:65992,4:49813,7:1049...
# 199976                                        5:1290,6:19
# 199977                                        3:17,7:1067
# 199978                                              6:107
# 199979  1:13014,3:2876,2:9425,5:10474,4:14697,7:7971,6...
# 199980    1:1866,3:2161,2:295,5:3931,4:5213,7:7173,6:5831
# 199981                                             7:1446
# 199982                      3:5912,2:271,5:2,4:2,7:15,6:2
# 199983                   1:2645,2:1300,5:610,4:5141,7:554
# 199984                                             3:4083
# 199985                                      1:2445,5:7560
# 199986                        3:1940,5:8047,4:2701,6:3897
# 199987                                   1:372,2:17,7:147
# 199988   1:2601,3:3036,2:5227,5:9024,4:8936,7:9255,6:1719
# 199989                                             3:2267
# 199990                          1:232,3:883,5:768,7:10971
# 199991  1:23492,3:40535,2:46237,5:18334,4:29587,7:2597...
# 199992         1:2563,3:2467,5:4531,4:2656,7:1292,6:13502
# 199993               1:62,3:118,2:1481,5:719,4:1020,6:119
# 199994  1:9054,3:21827,2:15612,5:32104,4:23270,7:22045...
# 199995                                             2:3901
# 199996          1:9072,3:5018,2:21771,5:5001,4:5890,6:988
# 199997                                  3:414,4:1480,7:44
# 199998     1:8514,3:657,2:3408,5:1861,4:6687,7:4474,6:583
# 199999                          3:196,5:497,4:1892,7:1473
#
#                                                    genres segment  \
# 0                  Cricket:82379,Kabaddi:255,Reality:4751     neg
# 1                              Cricket:15640,Wildlife:730     neg
# 2                                 LiveTV:13,Football:4129     neg
# 3                               TalkShow:658,Cricket:7690     neg
# 4                    Drama:5503,Cricket:3283,Reality:1345     neg
# 5                     Action:998,Drama:8795,Cricket:45541     neg
# 6       Action:963,TalkShow:18,Romance:1357,Mythology:...     neg
# 7                                 Drama:4344,Cricket:9956     neg
# 8                                  Cricket:1248,Comedy:70     neg
# 9       Action:86,Drama:4826,Cricket:10557,Kids:24,Tal...     neg
# 10                                             Drama:5597     neg
# 11                                   Mythology:9,Crime:12     neg
# 12      Drama:47986,Romance:21147,TalkShow:54,Family:7...     pos
# 13                               Romance:5242,Family:4186     neg
# 14                                              LiveTV:53     neg
# 15            Romance:64,Cricket:108,Sport:23,LiveTV:3903     neg
# 16                                             Drama:4930     neg
# 17                                              Family:20     neg
# 18      Drama:13179,Romance:11738,Action:9,Family:9369...     neg
# 19                              Comedy:23703,Reality:3779     neg
# 20                     Drama:17014,Romance:11,Comedy:1295     neg
# 21      Teen:4431,Drama:102,TalkShow:19131,Reality:479...     neg
# 22                               TalkShow:205,Cricket:983     neg
# 23              Action:26,Cricket:609,Comedy:2100,Sport:8     neg
# 24                                              Family:28     neg
# 25                                         TalkShow:10618     neg
# 26      Romance:1104,Drama:74,Cricket:2,Awards:94,Fami...     neg
# 27                    Drama:43694,Action:5006,Family:2919     neg
# 28                                            Action:3902     pos
# 29                                              Drama:641     neg
# ...                                                   ...     ...
# 199970                                         TalkShow:1     neg
# 199971                           Cricket:13583,Reality:12     neg
# 199972  Cricket:17251,TalkShow:75,Horror:38,Reality:18...     neg
# 199973                        Cricket:4057,Mythology:1170     neg
# 199974  Action:715,TalkShow:3364,Cricket:14505,Awards:...     neg
# 199975  Teen:193,Drama:28466,Mythology:102385,Family:4...     neg
# 199976                                        Comedy:1309     neg
# 199977                              Drama:1068,Cricket:16     neg
# 199978                                 Comedy:97,Crime:11     neg
# 199979  Comedy:6292,Drama:35106,Cricket:13498,Kids:281...     pos
# 199980  Drama:1283,TalkShow:9717,Cricket:8484,Comedy:6...     neg
# 199981                               Drama:9,Cricket:1437     neg
# 199982  Romance:241,Action:1621,Cricket:4080,Thriller:262     neg
# 199983                           Comedy:5109,Reality:5141     neg
# 199984                                        Action:4083     neg
# 199985                                       Comedy:10005     neg
# 199986  Romance:9472,TalkShow:1586,Cricket:233,Family:...     neg
# 199987                  Romance:8,Cricket:519,Thriller:10     neg
# 199988                Cricket:35319,Comedy:101,Crime:4388     neg
# 199989                                        Comedy:2267     neg
# 199990                         TalkShow:232,Cricket:12624     neg
# 199991  Drama:55492,Cricket:6269,Family:36340,TalkShow...     neg
# 199992                  Drama:10127,Awards:91,Crime:16793     neg
# 199993                 Comedy:110,Family:3123,Reality:286     pos
# 199994  Romance:21497,Family:4853,TalkShow:5770,Realit...     neg
# 199995                                      TalkShow:3901     neg
# 199996                                      Romance:47741     neg
# 199997                     LiveTV:1919,Cricket:18,Crime:1     neg
# 199998  Cricket:25113,Horror:24,Football:298,Crime:17,...     neg
# 199999                    Drama:164,Cricket:3889,Comedy:8     neg
#
#                                                    titles  \
# 0       Top Raids: Haryana vs Services SCB:103,Day 4: ...
# 1       Dhoni Quits Captaincy:148,Day 4: India Move in...
# 2       Star Sports 4:13,Manchester United vs Everton:...
# 3       SRH vs RCB:701,KKR vs KXIP:1042,MI vs SRH:2288...
# 4       MI vs KKR:304,Yeh Rishta Kya Kehlata Hai:5449,...
# 5       India vs Australia 2nd Test English:2836,SRH v...
# 6       Jodi:7222,Maapillai:1357,Mahabharatham:594,Ban...
# 7       Chandra Nandni:4344,India vs England 2nd T20I ...
# 8       India vs Bangladesh Day 2 English:1066,Fielder...
# 9       The Jungle Book:24,Jolly LLB:4826,Escape Plan:...
# 10                                     Lone Survivor:5597
# 11      Devon Ke Dev___ Mahadev:9,Har Yug Mein Aaega E...
# 12      Naamkarann:697,Chandra Nandni:1099,Pardes Mein...
# 13      Geet Hui Sabse Parayi:5242,Saath Nibhaana Saat...
# 14                                        Jalsa Movies:53
# 15      Vivah:49,Movies OK:354,Life Ok:69,Star Gold:6,...
# 16                  Chandra Nandni:4927,Mere Angne Mein:2
# 17                                               Tulli:20
# 18      Jolly LLB:2846,Chandra Nandni:10331,Ek Hazaaro...
# 19      Sirippu Da:29,Jodi:1330,Adhu Idhu Yedhu:138,Sa...
# 20      Naamkarann:16,Nagarjun Ek Yoddha:1085,Tanhaiya...
# 21      Kabali:2927,Life Ok:74,Dance  :4,Dance +:15454...
# 22      3rd T20I: Raina's 63 Steadies India:151,Jadhav...
# 23      Guru:26,India vs England | 2nd ODI | English:4...
# 24       Hum Aapke Hain Kaun:8,Saath Nibhaana Saathiya:20
# 25                                Koffee With Karan:10618
# 26      Star Parivaar Awards 2016:94,Ye Hai Mohabbatei...
# 27      Bharya:12928,Chandanamazha:12373,Chinthavishta...
# 28                            D - Underworld Badshah:3902
# 29                         Yeh Rishta Kya Kehlata Hai:641
# ...                                                   ...
# 199970                                Koffee With Karan:1
# 199971  Introducing Amazon Prime Video:12,India vs Eng...
# 199972  Mahabharat:9,Eng Salvage Pride India Win Serie...
# 199973  India vs Australia 1st Test English:758,India ...
# 199974  India vs England 1st T20I English:4499,101 nu ...
# 199975  Potol Kumar Gaanwala:8,Debadidev Mahadev:81,De...
# 199976                                Comedy Classes:1309
# 199977                          Kalash___Ek Vishwaas:1068
# 199978  Savdhaan India:11,The Great Indian Laughter Ch...
# 199979  MI vs KKR:28,India vs Bangladesh Day 2 English...
# 199980  Pakistan: Fall of Wickets:240,Australia vs Pak...
# 199981  India vs England 2nd T20I English:108,India vs...
# 199982  Phillauri:217,Kabali:1621,Hate Story 3:262,Ind...
# 199983  On Air With AIB:118,Futurama:4991,Masterchef A...
# 199984                                       Dishoom:4083
# 199985                          Gujjubhai The Great:10005
# 199986  Saravanan Meenatchi:1401,Pagal Nilavu:1666,Map...
# 199987  Rehna Hai Tere Dil Main:8,All-round Stokes Top...
# 199988  Dhoni Quits Captaincy:74,Oz Wrap Up 3-0 Whitew...
# 199989                        Bahu Humari Rajni_Kant:2267
# 199990  SRH vs RCB:865,Vintage Dhoni Comes Good with 1...
# 199991  Naamkarann:11963,Chandra Nandni:43,Twist Wala ...
# 199992  Yeh Rishta Kya Kehlata Hai:92,Lagori - Maitri ...
# 199993  Kalakka Povadhu Yaaru:110,Deivam Thandha Veedu...
# 199994  Masterchef Australia Season 7:61593,Sarabhai V...
# 199995                                   Neeya Naana:3901
# 199996  Geet Hui Sabse Parayi:315,Pyaar Kii Ye Ek Kaha...
# 199997  Savdhaan India:1,India vs England | 2nd ODI | ...
# 199998  Aus 1st Innings: Fall of Wickets:5,MI vs KKR:2...
# 199999  On Air With AIB:8,Sixers Hold Nerve to Win Sup...
#
#                                                       tod
# 0       10:26,13:331,12:323,20:21864,21:16233,17:7953,...
# 1       11:1661,10:384,20:401,21:798,22:221,16:525,19:...
# 2                                     1:1207,0:2406,2:529
# 3             11:71,20:2417,21:1042,23:2288,19:1872,8:658
# 4       20:158,22:4139,17:67,23:1510,19:288,18:56,0:23...
# 5       11:3450,10:1243,13:4420,12:4210,20:7050,21:770...
# 6             11:20,12:574,21:1357,22:1066,23:2290,0:4847
# 7       11:242,15:419,14:1877,22:309,19:3063,18:64,1:2...
# 8                    10:844,20:65,17:69,23:78,19:40,9:222
# 9       11:1,13:1610,12:2626,20:2325,21:2985,17:1252,1...
# 10                          18:402,15:1678,14:137,17:3380
# 11                                                  17:21
# 12      11:15355,10:90,13:20469,12:26603,15:20863,14:1...
# 13           15:2590,14:1164,22:473,23:3526,16:1488,0:187
# 14                                                  21:53
# 15       10:700,13:0,15:0,23:52,19:74,16:1268,9:1982,8:20
# 16                21:317,17:971,19:897,18:267,9:45,8:2432
# 17                                                  22:20
# 18      11:17,10:788,13:3826,12:4887,20:2043,22:2116,1...
# 19      11:2581,10:991,13:3557,12:3484,15:1626,14:2301...
# 20                                20:3727,21:5342,22:9251
# 21      12:227,15:5272,21:9333,17:6284,23:5898,19:2332...
# 22                 13:5,12:205,20:187,17:220,16:285,0:285
# 23                        9:2111,10:139,15:5,17:474,16:14
# 24                                                  16:28
# 25      13:2384,15:13,14:1363,17:3205,19:1790,18:1368,...
# 26              10:1104,15:2,21:405,22:1064,19:520,20:168
# 27      11:3623,13:1307,12:755,15:3115,14:221,22:2920,...
# 28                                          3:2283,4:1619
# 29                                           21:566,22:75
# ...                                                   ...
# 199970                                               19:1
# 199971      15:1905,21:2936,17:3329,16:3380,18:43,22:2001
# 199972  11:75,10:13,15:127,21:443,17:1349,16:758,19:59...
# 199973                       9:758,15:1661,14:1970,16:838
# 199974  11:114,10:0,13:2062,12:460,15:1312,17:2633,22:...
# 199975  11:9122,10:5671,13:13845,12:11808,15:17801,14:...
# 199976                                 13:11,14:8,16:1290
# 199977                                13:731,14:336,17:17
# 199978                                      8:6,7:5,18:96
# 199979  11:616,13:2095,15:2694,21:5545,17:1346,16:3533...
# 199980  13:3080,12:4351,20:2506,14:3133,17:15,16:295,1...
# 199981                         19:425,18:894,14:10,21:117
# 199982  10:179,15:22,21:247,17:2,16:1599,19:4089,7:26,...
# 199983         13:118,21:610,22:3945,23:436,1:2592,0:2549
# 199984                                 1:3081,0:496,2:506
# 199985      13:1210,12:3589,15:416,14:2400,22:1826,16:564
# 199986  11:54,13:1753,12:1976,20:478,21:643,22:2559,16...
# 199987                          19:17,10:372,13:10,18:137
# 199988  11:425,10:2832,13:1176,12:1737,20:8051,21:153,...
# 199989                                     21:1327,22:940
# 199990       20:3009,21:4112,17:17,16:357,18:2482,22:2877
# 199991  11:16475,10:6061,13:21399,12:16692,15:9352,14:...
# 199992  20:35,21:6604,22:10919,23:1793,0:1568,7:2400,9...
# 199993                               20:92,21:2704,22:723
# 199994  11:7445,10:4216,13:9832,12:6281,20:5774,14:210...
# 199995                              19:160,12:527,20:3214
# 199996  13:1814,20:2959,14:504,22:6795,23:6010,19:2117...
# 199997                          20:414,5:25,17:44,18:1455
# 199998  11:5935,10:3356,13:1341,12:466,20:512,14:2808,...
# 199999    20:509,14:789,17:105,19:610,18:268,3:1697,15:80
#
# [200000 rows x 7 columns]

# %%
#set index`
# train_data.reset_index( inplace = True)
train_data.rename(columns={'index':'ID'}, inplace=True)

test_data.reset_index( inplace = True)
test_data.rename(columns={'index':'ID'}, inplace=True)

# %%
#check data
print ('Train data has {} rows and {} columns'.format(train_data.shape[0],train_data.shape[1]))
print ('test_data data has {} rows and {} columns'.format(test_data.shape[0],test_data.shape[1]))
# Out:
# Train data has 200000 rows and 8 columns
# test_data data has 100000 rows and 6 columns

# %%
#Encode Target Variable
train_data = train_data.replace({'segment':{'pos':1,'neg':0}})

# %%
#check target variable count
train_data['segment'].value_counts()/train_data.shape[0]
# Out:
# 0    0.923725
# 1    0.076275
# Name: segment, dtype: float64

# %% [markdown]
# ### Creating separate columns for genres and dow variables

# %% [markdown]
# #### train data

# %%
train_data['g1'] = [re.sub(pattern='\:\d+',repl='',string=x) for x in train_data['genres']]
train_data['g1'] = train_data['g1'].apply(lambda x: x.split(','))

train_data['g2'] = [re.sub(pattern='\:\d+', repl='', string = x) for x in train_data['dow']]
train_data['g2'] = train_data['g2'].apply(lambda x: x.split(','))

t1 = pd.Series(train_data['g1']).apply(frozenset).to_frame(name='t_genre')
t2 = pd.Series(train_data['g2']).apply(frozenset).to_frame(name='t_dow')

# %%
# using frozenset trick - might take few minutes to process
for t_genre in frozenset.union(*t1.t_genre):
    t1[t_genre] = t1.apply(lambda _: int(t_genre in _.t_genre), axis=1)

# %%
for t_dow in frozenset.union(*t2.t_dow):
    t2[t_dow] = t2.apply(lambda _: int(t_dow in _.t_dow), axis = 1)

# %%
train_data = pd.concat([train_data.reset_index(drop=True), t1], axis=1)
train_data = pd.concat([train_data.reset_index(drop=True), t2], axis=1)

# %% [markdown]
# #### test data

# %%
test_data['g1'] = [re.sub(pattern='\:\d+',repl='',string=x) for x in test_data['genres']]
test_data['g1'] = test_data['g1'].apply(lambda x: x.split(','))

test_data['g2'] = [re.sub(pattern='\:\d+', repl='', string = x) for x in test_data['dow']]
test_data['g2'] = test_data['g2'].apply(lambda x: x.split(','))

t1_te = pd.Series(test_data['g1']).apply(frozenset).to_frame(name='t_genre')
t2_te = pd.Series(test_data['g2']).apply(frozenset).to_frame(name='t_dow')

# %%
for t_genre in frozenset.union(*t1_te.t_genre):
    t1_te[t_genre] = t1_te.apply(lambda _: int(t_genre in _.t_genre), axis=1)

# %%
for t_dow in frozenset.union(*t2_te.t_dow):
    t2_te[t_dow] = t2_te.apply(lambda _: int(t_dow in _.t_dow), axis = 1)

# %%
test_data = pd.concat([test_data.reset_index(drop=True), t1_te], axis=1)
test_data = pd.concat([test_data.reset_index(drop=True), t2_te], axis=1)

# %% [markdown]
# ### sum of watch time from titles

# %%
#the rows aren't list exactly. They are object, so we convert them to list and extract the watch time
w1 = train_data['titles']
w1 = w1.str.split(',')

#create a nested list of numbers
main = []
for i in np.arange(train_data.shape[0]):
    d1 = w1[i]
    nest = []
    nest = [re.sub(pattern = '.*\:', repl=' ', string= d1[k]) for k in list(np.arange(len(d1)))]
    main.append(nest)

# %% [markdown]
# #### Turns out, there are blank values in the list, we need to fix them before we could add
# #### Fixing blanks in the list now

# %%
blanks = []
for i in np.arange(len(main)):
    if '' in main[i]:
#         print "{} blanks found".format(len(blanks))
        blanks.append(i)
        
#replacing blanks with 0
for i in blanks:
    main[i] = [x.replace('','0') for x in main[i]]
    
#converting string to integers
main = [[int(y) for y in x] for x in main]

#adding the watch time
tosum = []
for i in np.arange(len(main)):
    s = sum(main[i])
    tosum.append(s)

# %%
train_data['title_sum'] = tosum

# %%
#making changes in test data
w1_te = test_data['titles']
w1_te = w1_te.str.split(',')

# %%
main_te = []
for i in np.arange(test_data.shape[0]):
    d1 = w1_te[i]
    nest = []
    nest = [re.sub(pattern = '.*\:', repl=' ', string= d1[k]) for k in list(np.arange(len(d1)))]
    main_te.append(nest)

# %%
blanks_te = []
for i in np.arange(len(main_te)):
    if '' in main_te[i]:
#         print "{} blanks found".format(len(blanks_te))
        blanks_te.append(i)
        
#replacing blanks with 0
for i in blanks_te:
    main_te[i] = [x.replace('','0') for x in main_te[i]]
    
#converting string to integers
main_te = [[int(y) for y in x] for x in main_te]

#adding the watch time
tosum_te = []
for i in np.arange(len(main_te)):
    s = sum(main_te[i])
    tosum_te.append(s)

# %%
test_data['title_sum'] = tosum_te

# %% [markdown]
# ### create count variables

# %%
#count variables
def wcount(p):
    return p.count(',')+1

# %%
train_data['title_count'] = train_data['titles'].map(wcount)
train_data['genres_count'] = train_data['genres'].map(wcount)
train_data['cities_count'] = train_data['cities'].map(wcount)
train_data['tod_count'] = train_data['tod'].map(wcount)
train_data['dow_count'] = train_data['dow'].map(wcount)


test_data['title_count'] = test_data['titles'].map(wcount)
test_data['genres_count'] = test_data['genres'].map(wcount)
test_data['cities_count'] = test_data['cities'].map(wcount)
test_data['tod_count'] = test_data['tod'].map(wcount)
test_data['dow_count'] = test_data['dow'].map(wcount)

# %% [markdown]
# ### remove variables

# %%
test_id = test_data['ID']
train_data.drop(['ID','cities','dow','genres','titles','tod','g1','g2','t_genre','t_dow'], inplace=True, axis=1)
test_data.drop(['ID','cities','dow','genres','titles','tod','g1','g2','t_genre','t_dow'], inplace=True, axis=1)

# %% [markdown]
# ### training data

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.model_selection import train_test_split
# Out:
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/gauravk/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
target = train_data['segment']
train_data.drop('segment',axis=1, inplace=True)

# %%
## uncomment to do grid search - could get better score
# X_train, X_val, y_train, y_val = train_test_split(train_data, target, train_size=0.6, random_state = 1)

## doing grid search for parameters
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.grid_search import GridSearchCV
# from sklearn.metrics import roc_auc_score, make_scorer
# clf_scorer = make_scorer('roc_auc')
# rfc = RandomForestClassifier(n_estimators=100,oob_score=True,)
# param_grid = {
#     'max_depth':[4,8,12],
#     'max_features':['sqrt',10,15]
    
# }

# cv_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=5, scoring=clf_scorer)
# cv_rfc.best_params_

# %%
#train final model
rf_model = RandomForestClassifier(n_estimators=5,max_depth=12, max_features=10)
rf_model.fit(train_data, target)

# %%
#make prediction
rf_pred = rf_model.predict_proba(test_data)

# %%
#make submission file and submit
columns = ['segment']
sub = pd.DataFrame(data=rf_pred[:,1], columns=columns)
sub['ID'] = test_id
sub = sub[['ID','segment']]
sub.to_csv("sub_hot.csv", index=False)
