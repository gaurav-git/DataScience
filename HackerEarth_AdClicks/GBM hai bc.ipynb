# %% [markdown]
# # randam GBM by gaurav

# %% [markdown]
# ### Load libraries and data

# %%
import pandas as pd
import numpy as np
# import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %% [markdown]
# ### Clean Data and Create Features

# %% [markdown]
# ### Model Training

# %%
train = pd.read_csv("small_train.csv")
# test = pd.read_csv("test.csv")

# %%
train = train.drop(train.columns[0], axis=1)

# %%
train.head()
# Out:
#           ID             datetime  siteid  offerid  category  merchant  \
# 0  IDWhPMKJ0  2017-01-11 17:12:49  248011   643491        29       255
# 1  IDjzNMxRJ  2017-01-14 09:27:49  224549   122712        88       127
# 2  IDsKAZsoY  2017-01-20 15:42:57       0    31042       254       669
# 3  IDeca0XWf  2017-01-17 17:56:39  182851   192967       254       669
# 4  IDA85VPro  2017-01-17 15:40:25   41836   120260        48       178
#
#    countrycode  browserid  devid  click  tweekday  thour  tminute
# 0            0          1      3      0         2     17       12
# 1            4          8      0      0         5      9       27
# 2            4          7      2      0         4     15       42
# 3            3          3      1      0         1     17       56
# 4            1          2      1      0         1     15       40

# %%
cols_to_use = list(set(train.columns) - set(['ID','datetime','click']))
print(cols_to_use)
# Out:
# ['siteid', 'merchant', 'tminute', 'thour', 'offerid', 'devid', 'tweekday', 'browserid', 'category', 'countrycode']

# %%
# from sklearn.model_selection import StratifiedKFold
# skf = StratifiedKFold(n_splits=20, random_state=42)
# a = 0
# for i, j in skf.split(train[cols_to_use], train['click']):
#     a = j
# len(a)
# # train.loc[a].to_csv("small_train.csv")

# %%
X_train, X_test, y_train, y_test = train_test_split(train[cols_to_use], train['click'], test_size = 0.5, random_state=42)

# %% [markdown]
# # For trial

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import time
t1 = time.time()
dict3 = {}
dict4 = {}
# for i in [20, 40, 50, 60, 70, 80, 90]:

# print("Model with ", i, " max_features ")
model_mod = GradientBoostingClassifier(random_state=42)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
start = time.time()
model_mod.fit(X_train[cols_to_use], y_train)
print("time to fit: ", time.time()-start)
start = time.time()
pred = model_mod.predict(X_test)
print("time to predict: ", time.time()-start ,"\n")
print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
print("crossval score: ", roc_auc_score(y_test, pred))
# print("oob score: ", model_mod.oob_score_)
# dict3[i]=roc_auc_score(y_test, pred)
# dict4[i]=model_mod.oob_score_
# print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  23.71186399459839
# time to predict:  0.4553244113922119
#
# training score:  0.818606946132
# crossval score:  0.819646507308
# total time  24.709604263305664

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import time
t1 = time.time()
dict3 = {}
dict4 = {}
for i in range(50, 750, 25):

    # print("Model with ", i, " max_features ")
    model_mod = GradientBoostingClassifier(n_estimators=i, random_state=42)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(X_train[cols_to_use], y_train)
    print("time to fit: ", time.time()-start)
    start = time.time()
    pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
    print("crossval score: ", roc_auc_score(y_test, pred))
    # print("oob score: ", model_mod.oob_score_)
    # dict3[i]=roc_auc_score(y_test, pred)
    # dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  12.637024164199829
# time to predict:  0.25017714500427246
#
# training score:  0.790904462428
# crossval score:  0.79382325317
# Done ::  50
# time to fit:  18.41711401939392
# time to predict:  0.3412599563598633
#
# training score:  0.807926002626
# crossval score:  0.810248587954
# Done ::  75
# time to fit:  24.164186239242554
# time to predict:  0.434309720993042
#
# training score:  0.818606946132
# crossval score:  0.819646507308
# Done ::  100
# time to fit:  27.5926570892334
# time to predict:  0.7625212669372559
#
# training score:  0.819573326738
# crossval score:  0.820301006608
# Done ::  125
# time to fit:  35.171058177948
# time to predict:  0.6204419136047363
#
# training score:  0.819893539047
# crossval score:  0.820261160789
# Done ::  150
# time to fit:  42.37921714782715
# time to predict:  0.7044978141784668
#
# training score:  0.820215241906
# crossval score:  0.820731093088
# Done ::  175
# time to fit:  48.154276609420776
# time to predict:  1.10178542137146
#
# training score:  0.821441798899
# crossval score:  0.820818806738
# Done ::  200
# time to fit:  51.20448017120361
# time to predict:  0.8606116771697998
#
# training score:  0.821176713825
# crossval score:  0.820603533619
# Done ::  225
# time to fit:  56.74142098426819
# time to predict:  0.9486730098724365
#
# training score:  0.8217092486
# crossval score:  0.820953270527
# Done ::  250
# time to fit:  67.62915349006653
# time to predict:  1.4039971828460693
#
# training score:  0.822576940262
# crossval score:  0.82141235356
# Done ::  275
# time to fit:  108.16602826118469
# time to predict:  2.23559308052063
#
# training score:  0.822335563631
# crossval score:  0.821309845697
# Done ::  300
# time to fit:  203.55803275108337
# time to predict:  1.239861249923706
#
# training score:  0.822885189092
# crossval score:  0.821682924645
# Done ::  325
# time to fit:  130.11769342422485
# time to predict:  1.3539857864379883
#
# training score:  0.823234018529
# crossval score:  0.821067219532
# Done ::  350
# time to fit:  228.2555878162384
# time to predict:  2.4507458209991455
#
# training score:  0.823623647095
# crossval score:  0.820746545235
# Done ::  375
# time to fit:  159.9879720211029
# time to predict:  2.524799346923828
#
# training score:  0.824166436281
# crossval score:  0.821020535451
# Done ::  400
# time to fit:  272.9334337711334
# time to predict:  1.6341867446899414
#
# training score:  0.82439948609
# crossval score:  0.820612147504
# Done ::  425
# time to fit:  156.39543676376343
# time to predict:  1.6301615238189697
#
# training score:  0.825233214899
# crossval score:  0.820676519113
# Done ::  450
# time to fit:  102.54604768753052
# time to predict:  1.7071897983551025
#
# training score:  0.825488482599
# crossval score:  0.820244789126
# Done ::  475
# time to fit:  106.9371588230133
# time to predict:  1.745269775390625
#
# training score:  0.82580825787
# crossval score:  0.820358146256
# Done ::  500
# time to fit:  112.27798271179199
# time to predict:  1.8303043842315674
#
# training score:  0.826388428047
# crossval score:  0.820454407732
# Done ::  525
# time to fit:  117.19749307632446
# time to predict:  1.9083583354949951
#
# training score:  0.826932926302
# crossval score:  0.820473212951
# Done ::  550
# time to fit:  122.47822761535645
# time to predict:  1.9944202899932861
#
# training score:  0.827317427662
# crossval score:  0.819848960011
# Done ::  575
# time to fit:  127.54686236381531
# time to predict:  2.060467481613159
#
# training score:  0.827365063065
# crossval score:  0.819750988969
# Done ::  600
# time to fit:  132.87768530845642
# time to predict:  2.1385247707366943
#
# training score:  0.82803708591
# crossval score:  0.819678661408
# Done ::  625
# time to fit:  138.6127483844757
# time to predict:  2.2275867462158203
#
# training score:  0.828600165401
# crossval score:  0.819503234108
# Done ::  650
# time to fit:  143.58030724525452
# time to predict:  2.3046298027038574
#
# training score:  0.828852014964
# crossval score:  0.819653609802
# Done ::  675
# time to fit:  148.5808186531067
# time to predict:  2.3997092247009277
#
# training score:  0.829160045274
# crossval score:  0.819473053806
# Done ::  700
# time to fit:  153.9646816253662
# time to predict:  2.4547483921051025
#
# training score:  0.828950922427
# crossval score:  0.819393887983
# Done ::  725
# total time  3137.6712172031403

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import roc_auc_score
import time
t1 = time.time()
dict3 = {}
dict4 = {}
for i in range(2, 12, 1):

    # print("Model with ", i, " max_features ")
    model_mod = GradientBoostingClassifier(n_estimators=100, random_state=42, max_depth =i)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(X_train[cols_to_use], y_train)
    print("time to fit: ", time.time()-start)
    start = time.time()
    pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
    print("crossval score: ", roc_auc_score(y_test, pred))
    # print("oob score: ", model_mod.oob_score_)
    # dict3[i]=roc_auc_score(y_test, pred)
    # dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  14.413289785385132
# time to predict:  0.3182227611541748
#
# training score:  0.795734398779
# crossval score:  0.799850443396
# Done ::  2
# time to fit:  22.023663997650146
# time to predict:  0.4893484115600586
#
# training score:  0.818606946132
# crossval score:  0.819646507308
# Done ::  3
# time to fit:  32.07785081863403
# time to predict:  0.544384241104126
#
# training score:  0.829009569054
# crossval score:  0.828416820649
# Done ::  4
# time to fit:  47.125579833984375
# time to predict:  0.6614687442779541
#
# training score:  0.831485775011
# crossval score:  0.828003370064
# Done ::  5
# time to fit:  69.12024211883545
# time to predict:  0.760535478591919
#
# training score:  0.835993212602
# crossval score:  0.826283288377
# Done ::  6
# time to fit:  101.86256623268127
# time to predict:  0.9486474990844727
#
# training score:  0.84577214273
# crossval score:  0.824886116368
# Done ::  7
# time to fit:  159.55466604232788
# time to predict:  1.0457408428192139
#
# training score:  0.861104522633
# crossval score:  0.821289724612
# Done ::  8
# time to fit:  250.5995156764984
# time to predict:  1.2278766632080078
#
# training score:  0.880222972812
# crossval score:  0.816995108848
# Done ::  9
# time to fit:  361.69466257095337
# time to predict:  1.3689746856689453
#
# training score:  0.899458256129
# crossval score:  0.813627273034
# Done ::  10
# time to fit:  524.0843226909637
# time to predict:  1.5611331462860107
#
# training score:  0.93045133655
# crossval score:  0.808329078993
# Done ::  11
# total time  1600.9825327396393

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import roc_auc_score
# import time
t1 = time.time()
dict3 = {}
dict4 = {}
for i in range(2, 200, 3):

    # print("Model with ", i, " max_features ")
    model_mod = GradientBoostingClassifier(n_estimators=100, random_state=42, min_samples_leaf=i)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(X_train[cols_to_use], y_train)
    print("time to fit: ", time.time()-start)
    start = time.time()
    pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
    print("crossval score: ", roc_auc_score(y_test, pred))
    # print("oob score: ", model_mod.oob_score_)
    # dict3[i]=roc_auc_score(y_test, pred)
    # dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  21.984633684158325
# time to predict:  0.43030643463134766
#
# training score:  0.820690284816
# crossval score:  0.821733421557
# Done ::  2
# time to fit:  21.788525581359863
# time to predict:  0.41528964042663574
#
# training score:  0.814453722792
# crossval score:  0.815449928643
# Done ::  5
# time to fit:  22.01568341255188
# time to predict:  0.4383094310760498
#
# training score:  0.816588333537
# crossval score:  0.817440581416
# Done ::  8
# time to fit:  22.036700963974
# time to predict:  0.4383096694946289
#
# training score:  0.81817331882
# crossval score:  0.819627176272
# Done ::  11
# time to fit:  21.930633544921875
# time to predict:  0.42330288887023926
#
# training score:  0.818181864163
# crossval score:  0.819402763452
# Done ::  14
# time to fit:  22.034669637680054
# time to predict:  0.4393124580383301
#
# training score:  0.818001576964
# crossval score:  0.819227336153
# Done ::  17
# time to fit:  21.948607444763184
# time to predict:  0.4293055534362793
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  20
# time to fit:  21.890594959259033
# time to predict:  0.4383280277252197
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  23
# time to fit:  22.113728284835815
# time to predict:  0.43731117248535156
#
# training score:  0.818018449131
# crossval score:  0.819174931501
# Done ::  26
# time to fit:  21.980658292770386
# time to predict:  0.4383118152618408
#
# training score:  0.818345060676
# crossval score:  0.819608371054
# Done ::  29
# time to fit:  21.981664419174194
# time to predict:  0.42530179023742676
#
# training score:  0.818397823285
# crossval score:  0.819776960092
# Done ::  32
# time to fit:  22.089734315872192
# time to predict:  0.4372892379760742
#
# training score:  0.818397823285
# crossval score:  0.819776960092
# Done ::  35
# time to fit:  21.9676730632782
# time to predict:  0.42530059814453125
#
# training score:  0.818884213205
# crossval score:  0.820353937076
# Done ::  38
# time to fit:  21.8745858669281
# time to predict:  0.43328213691711426
#
# training score:  0.820074661237
# crossval score:  0.821092664838
# Done ::  41
# time to fit:  21.899603366851807
# time to predict:  0.42330288887023926
#
# training score:  0.820074661237
# crossval score:  0.821092664838
# Done ::  44
# time to fit:  22.06371569633484
# time to predict:  0.4383082389831543
#
# training score:  0.81772430989
# crossval score:  0.81901489029
# Done ::  47
# time to fit:  21.88359045982361
# time to predict:  0.4383120536804199
#
# training score:  0.81772430989
# crossval score:  0.819013180724
# Done ::  50
# time to fit:  22.080732822418213
# time to predict:  0.4413132667541504
#
# training score:  0.81772430989
# crossval score:  0.819013180724
# Done ::  53
# time to fit:  21.99967074394226
# time to predict:  0.44031190872192383
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  56
# time to fit:  21.926644325256348
# time to predict:  0.42330265045166016
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  59
# time to fit:  21.877585411071777
# time to predict:  0.425304651260376
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  62
# time to fit:  21.79652762413025
# time to predict:  0.42330217361450195
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  65
# time to fit:  22.01265287399292
# time to predict:  0.44031333923339844
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  68
# time to fit:  22.139775276184082
# time to predict:  0.43630433082580566
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  71
# time to fit:  22.00467324256897
# time to predict:  0.4253051280975342
#
# training score:  0.816052599145
# crossval score:  0.817768685849
# Done ::  74
# time to fit:  21.865579843521118
# time to predict:  0.42530345916748047
#
# training score:  0.816052599145
# crossval score:  0.817812542674
# Done ::  77
# time to fit:  21.912610054016113
# time to predict:  0.4243144989013672
#
# training score:  0.816052599145
# crossval score:  0.817812542674
# Done ::  80
# time to fit:  21.94262957572937
# time to predict:  0.433307409286499
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  83
# time to fit:  21.977654933929443
# time to predict:  0.43930840492248535
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  86
# time to fit:  21.891595602035522
# time to predict:  0.4343080520629883
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  89
# time to fit:  22.011682271957397
# time to predict:  0.43932604789733887
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  92
# time to fit:  21.920592308044434
# time to predict:  0.4363102912902832
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  95
# time to fit:  21.883593320846558
# time to predict:  0.42130017280578613
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  98
# time to fit:  21.966618299484253
# time to predict:  0.4413137435913086
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  101
# time to fit:  22.0416738986969
# time to predict:  0.4363102912902832
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  104
# time to fit:  21.872581481933594
# time to predict:  0.4383080005645752
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  107
# time to fit:  21.804553747177124
# time to predict:  0.42630887031555176
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  110
# time to fit:  21.908605575561523
# time to predict:  0.4303102493286133
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  113
# time to fit:  21.88459300994873
# time to predict:  0.43930959701538086
#
# training score:  0.816098525479
# crossval score:  0.817812542674
# Done ::  116
# time to fit:  22.053712606430054
# time to predict:  0.43931102752685547
#
# training score:  0.816052599145
# crossval score:  0.817812542674
# Done ::  119
# time to fit:  21.975653171539307
# time to predict:  0.438309907913208
#
# training score:  0.816050890076
# crossval score:  0.817858109064
# Done ::  122
# time to fit:  22.040703296661377
# time to predict:  0.4392859935760498
#
# training score:  0.816050890076
# crossval score:  0.817858109064
# Done ::  125
# time to fit:  21.83554458618164
# time to predict:  0.4222755432128906
#
# training score:  0.816050890076
# crossval score:  0.817858109064
# Done ::  128
# time to fit:  21.97062611579895
# time to predict:  0.42432308197021484
#
# training score:  0.816004963742
# crossval score:  0.817858109064
# Done ::  131
# time to fit:  21.915611743927002
# time to predict:  0.4232785701751709
#
# training score:  0.816004963742
# crossval score:  0.817858109064
# Done ::  134
# time to fit:  21.922618627548218
# time to predict:  0.4453139305114746
#
# training score:  0.817295809785
# crossval score:  0.818666862947
# Done ::  137
# time to fit:  21.931620836257935
# time to predict:  0.442288875579834
#
# training score:  0.817295809785
# crossval score:  0.818666862947
# Done ::  140
# time to fit:  22.175798177719116
# time to predict:  0.42530226707458496
#
# training score:  0.818904722029
# crossval score:  0.819655647009
# Done ::  143
# time to fit:  22.94835138320923
# time to predict:  0.4593205451965332
#
# training score:  0.818903012961
# crossval score:  0.819699503834
# Done ::  146
# time to fit:  22.342939376831055
# time to predict:  0.43130970001220703
#
# training score:  0.818947230226
# crossval score:  0.819745070224
# Done ::  149
# time to fit:  21.955636262893677
# time to predict:  0.43531036376953125
#
# training score:  0.818709053212
# crossval score:  0.819647099182
# Done ::  152
# time to fit:  22.031694650650024
# time to predict:  0.4413135051727295
#
# training score:  0.81935202189
# crossval score:  0.820236043125
# Done ::  155
# time to fit:  21.920616149902344
# time to predict:  0.434307336807251
#
# training score:  0.814096566531
# crossval score:  0.816220020455
# Done ::  158
# time to fit:  21.914613962173462
# time to predict:  0.4313018321990967
#
# training score:  0.814096566531
# crossval score:  0.816220020455
# Done ::  161
# time to fit:  21.93663191795349
# time to predict:  0.42627787590026855
#
# training score:  0.813916279332
# crossval score:  0.816699026398
# Done ::  164
# time to fit:  21.923620462417603
# time to predict:  0.44131016731262207
# training score:  0.813916279332
# crossval score:  0.816699026398
# Done ::  167
# time to fit:  21.837557315826416
# time to predict:  0.43330860137939453
#
# training score:  0.818003067513
# crossval score:  0.819611790184
# Done ::  170
# time to fit:  21.870583534240723
# time to predict:  0.43430614471435547
#
# training score:  0.817833034726
# crossval score:  0.81941242897
# Done ::  173
# time to fit:  21.97165322303772
# time to predict:  0.43931150436401367
#
# training score:  0.817833034726
# crossval score:  0.81941242897
# Done ::  176
# time to fit:  21.92561960220337
# time to predict:  0.4413115978240967
#
# training score:  0.815611917039
# crossval score:  0.817425787202
# Done ::  179
# time to fit:  21.952641487121582
# time to predict:  0.43931007385253906
#
# training score:  0.817957141179
# crossval score:  0.819653937444
# Done ::  182
# time to fit:  21.928619384765625
# time to predict:  0.427309513092041
#
# training score:  0.817316100089
# crossval score:  0.818599072207
# Done ::  185
# time to fit:  22.025688648223877
# time to predict:  0.44231390953063965
#
# training score:  0.817316100089
# crossval score:  0.818599072207
# Done ::  188
# time to fit:  21.841535091400146
# time to predict:  0.4263310432434082
#
# training score:  0.816122233921
# crossval score:  0.818050040143
# Done ::  191
# time to fit:  22.118757009506226
# time to predict:  0.4413115978240967
#
# training score:  0.818526838424
# crossval score:  0.820750358066
# Done ::  194
# time to fit:  21.797500133514404
# time to predict:  0.428333044052124
#
# training score:  0.818525129356
# crossval score:  0.820750358066
# Done ::  197
# total time  1511.907054424286

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import roc_auc_score
# import time
t1 = time.time()
dict3 = {}
dict4 = {}
for i in range(2, 30, 1):

    # print("Model with ", i, " max_features ")
    model_mod = GradientBoostingClassifier(n_estimators=100, random_state=42, min_samples_leaf=i)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(X_train[cols_to_use], y_train)
    print("time to fit: ", time.time()-start)
    start = time.time()
    pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
    print("crossval score: ", roc_auc_score(y_test, pred))
    # print("oob score: ", model_mod.oob_score_)
    # dict3[i]=roc_auc_score(y_test, pred)
    # dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  21.898595809936523
# time to predict:  0.42328429222106934
#
# training score:  0.820690284816
# crossval score:  0.821733421557
# Done ::  2
# time to fit:  21.865580558776855
# time to predict:  0.4322810173034668
#
# training score:  0.819926846342
# crossval score:  0.820498592199
# Done ::  3
# time to fit:  21.84456157684326
# time to predict:  0.434307336807251
#
# training score:  0.814363579193
# crossval score:  0.816378352101
# Done ::  4
# time to fit:  22.08673667907715
# time to predict:  0.4242990016937256
#
# training score:  0.814453722792
# crossval score:  0.815449928643
# Done ::  5
# time to fit:  21.786498308181763
# time to predict:  0.43132829666137695
#
# training score:  0.816222413412
# crossval score:  0.818390637349
# Done ::  6
# time to fit:  21.69745945930481
# time to predict:  0.42029666900634766
#
# training score:  0.816222413412
# crossval score:  0.818388927784
# Done ::  7
# time to fit:  22.05070734024048
# time to predict:  0.4313051700592041
#
# training score:  0.816588333537
# crossval score:  0.817440581416
# Done ::  8
# time to fit:  21.996673345565796
# time to predict:  0.43730950355529785
#
# training score:  0.814819642917
# crossval score:  0.816112383896
# Done ::  9
# time to fit:  22.09574007987976
# time to predict:  0.43731164932250977
#
# training score:  0.818743016066
# crossval score:  0.820261094731
# Done ::  10
# time to fit:  22.066720485687256
# time to predict:  0.45632123947143555
#
# training score:  0.81817331882
# crossval score:  0.819627176272
# Done ::  11
# time to fit:  21.984659910202026
# time to predict:  0.4383091926574707
#
# training score:  0.81817331882
# crossval score:  0.819627176272
# Done ::  12
# time to fit:  21.927621364593506
# time to predict:  0.4292869567871094
#
# training score:  0.81817331882
# crossval score:  0.819627176272
# Done ::  13
# time to fit:  21.914610862731934
# time to predict:  0.4413139820098877
#
# training score:  0.818181864163
# crossval score:  0.819402763452
# Done ::  14
# time to fit:  21.86257529258728
# time to predict:  0.4242982864379883
#
# training score:  0.818181864163
# crossval score:  0.819402763452
# Done ::  15
# time to fit:  21.927620887756348
# time to predict:  0.4383091926574707
#
# training score:  0.818181864163
# crossval score:  0.819402763452
# Done ::  16
# time to fit:  21.937626361846924
# time to predict:  0.43928956985473633
#
# training score:  0.818001576964
# crossval score:  0.819227336153
# Done ::  17
# time to fit:  21.871580600738525
# time to predict:  0.4242994785308838
#
# training score:  0.818001576964
# crossval score:  0.819227336153
# Done ::  18
# time to fit:  21.966651678085327
# time to predict:  0.43928980827331543
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  19
# time to fit:  21.875556468963623
# time to predict:  0.43030571937561035
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  20
# time to fit:  21.942604303359985
# time to predict:  0.4413139820098877
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  21
# time to fit:  21.85857057571411
# time to predict:  0.4243028163909912
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  22
# time to fit:  21.945626735687256
# time to predict:  0.4363076686859131
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  23
# time to fit:  21.889595985412598
# time to predict:  0.43530702590942383
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  24
# time to fit:  21.938600778579712
# time to predict:  0.43330860137939453
#
# training score:  0.818001576964
# crossval score:  0.819229045718
# Done ::  25
# time to fit:  21.875577688217163
# time to predict:  0.436307430267334
#
# training score:  0.818018449131
# crossval score:  0.819174931501
# Done ::  26
# time to fit:  21.875606536865234
# time to predict:  0.43230533599853516
#
# training score:  0.818435204276
# crossval score:  0.819696084703
# Done ::  27
# time to fit:  21.949605226516724
# time to predict:  0.43831658363342285
#
# training score:  0.818435204276
# crossval score:  0.819696084703
# Done ::  28
# time to fit:  21.814512252807617
# time to predict:  0.4273040294647217
#
# training score:  0.818345060676
# crossval score:  0.819608371054
# Done ::  29
# total time  639.8487944602966

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import GradientBoostingClassifier
# from sklearn.metrics import roc_auc_score
# import time
t1 = time.time()
dict3 = {}
dict4 = {}
for i in range(2, 90, 1):

    # print("Model with ", i, " max_features ")
    model_mod = GradientBoostingClassifier(n_estimators=100, random_state=42, min_samples_split =i)#(n_estimators=470, min_samples_split=i, verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(X_train[cols_to_use], y_train)
    print("time to fit: ", time.time()-start)
    start = time.time()
    pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
    print("crossval score: ", roc_auc_score(y_test, pred))
    # print("oob score: ", model_mod.oob_score_)
    # dict3[i]=roc_auc_score(y_test, pred)
    # dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# time to fit:  21.95161485671997
# time to predict:  0.43330860137939453
#
# training score:  0.818606946132
# crossval score:  0.819646507308
# Done ::  2
# time to fit:  21.902606964111328
# time to predict:  0.43530750274658203
#
# training score:  0.818606946132
# crossval score:  0.819646507308
# Done ::  3
# time to fit:  22.065720558166504
# time to predict:  0.4363105297088623
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  4
# time to fit:  21.953630208969116
# time to predict:  0.43131065368652344
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  5
# time to fit:  21.865551233291626
# time to predict:  0.4373316764831543
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  6
# time to fit:  21.81053614616394
# time to predict:  0.4333071708679199
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  7
# time to fit:  21.86657166481018
# time to predict:  0.4293055534362793
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  8
# time to fit:  21.902955055236816
# time to predict:  0.4212973117828369
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  9
# time to fit:  22.289878368377686
# time to predict:  0.43730878829956055
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  10
# time to fit:  21.837582111358643
# time to predict:  0.4353058338165283
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  11
# time to fit:  21.776537656784058
# time to predict:  0.42029690742492676
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  12
# time to fit:  21.860595703125
# time to predict:  0.4333057403564453
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  13
# time to fit:  21.916614055633545
# time to predict:  0.43931055068969727
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  14
# time to fit:  21.953661918640137
# time to predict:  0.4223005771636963
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  15
# time to fit:  21.90760350227356
# time to predict:  0.43331098556518555
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  16
# time to fit:  21.8956196308136
# time to predict:  0.43430352210998535
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  17
# time to fit:  21.94265842437744
# time to predict:  0.4363071918487549
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  18
# time to fit:  21.787519216537476
# time to predict:  0.429302453994751
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  19
# time to fit:  21.90660262107849
# time to predict:  0.44231748580932617
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  20
# time to fit:  21.99166703224182
# time to predict:  0.4223005771636963
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  21
# time to fit:  21.8435640335083
# time to predict:  0.4293029308319092
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  22
# time to fit:  21.84456491470337
# time to predict:  0.4262993335723877
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  23
# time to fit:  21.864551067352295
# time to predict:  0.4323086738586426
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  24
# time to fit:  21.712494134902954
# time to predict:  0.42130112648010254
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  25
# time to fit:  21.815540075302124
# time to predict:  0.43730807304382324
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  26
# time to fit:  21.989665269851685
# time to predict:  0.42029786109924316
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  27
# time to fit:  21.965645790100098
# time to predict:  0.43730616569519043
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  28
# time to fit:  22.03969979286194
# time to predict:  0.43730902671813965
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  29
# time to fit:  21.883588314056396
# time to predict:  0.4363138675689697
#
# training score:  0.817773654362
# crossval score:  0.818935132592
# Done ::  30
# time to fit:  22.1747944355011
# time to predict:  0.43230676651000977
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  31
# time to fit:  22.089736938476562
# time to predict:  0.4363079071044922
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  32
# time to fit:  21.969650745391846
# time to predict:  0.42830443382263184
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  33
# time to fit:  21.818543434143066
# time to predict:  0.43430614471435547
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  34
# time to fit:  21.7524676322937
# time to predict:  0.4293060302734375
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  35
# time to fit:  21.766507863998413
# time to predict:  0.41930150985717773
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  36
# time to fit:  22.009704113006592
# time to predict:  0.4293043613433838
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  37
# time to fit:  21.969653606414795
# time to predict:  0.4363069534301758
#
# training score:  0.818175027889
# crossval score:  0.819240420801
# Done ::  38
# time to fit:  21.70348858833313
# time to predict:  0.42029571533203125
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  39
# time to fit:  21.80656099319458
# time to predict:  0.43230533599853516
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  40
# time to fit:  21.77653670310974
# time to predict:  0.4363081455230713
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  41
# time to fit:  21.85559868812561
# time to predict:  0.43630456924438477
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  42
# time to fit:  21.91158175468445
# time to predict:  0.4293055534362793
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  43
# time to fit:  21.7134952545166
# time to predict:  0.4643268585205078
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  44
# time to fit:  21.827550172805786
# time to predict:  0.4333045482635498
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  45
# time to fit:  21.793524742126465
# time to predict:  0.4383096694946289
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  46
# time to fit:  21.82154393196106
# time to predict:  0.4583268165588379
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  47
# time to fit:  21.83057713508606
# time to predict:  0.43531322479248047
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  48
# time to fit:  21.884587049484253
# time to predict:  0.43731164932250977
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  49
# time to fit:  21.814540147781372
# time to predict:  0.4333062171936035
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  50
# time to fit:  21.772509336471558
# time to predict:  0.4353063106536865
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  51
# time to fit:  21.77350664138794
# time to predict:  0.4343075752258301
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  52
# time to fit:  21.71946883201599
# time to predict:  0.4293093681335449
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  53
# time to fit:  21.99169373512268
# time to predict:  0.43530797958374023
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  54
# time to fit:  21.741488456726074
# time to predict:  0.43430590629577637
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  55
# time to fit:  21.84356379508972
# time to predict:  0.4313046932220459
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  56
# time to fit:  21.76450753211975
# time to predict:  0.42730069160461426
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  57
# time to fit:  21.789549112319946
# time to predict:  0.4363076686859131
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  58
# time to fit:  21.82554793357849
# time to predict:  0.4263014793395996
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  59
# time to fit:  21.865577697753906
# time to predict:  0.42330026626586914
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  60
# time to fit:  21.94663715362549
# time to predict:  0.4293093681335449
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  61
# time to fit:  21.852569103240967
# time to predict:  0.43730998039245605
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  62
# time to fit:  21.99466586112976
# time to predict:  0.42130303382873535
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  63
# time to fit:  21.779513835906982
# time to predict:  0.4333336353302002
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  64
# time to fit:  21.898601055145264
# time to predict:  0.4192979335784912
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  65
# time to fit:  21.83558177947998
# time to predict:  0.4363093376159668
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  66
# time to fit:  21.825570106506348
# time to predict:  0.43530774116516113
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  67
# time to fit:  21.828575611114502
# time to predict:  0.4353060722351074
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  68
# time to fit:  21.892598390579224
# time to predict:  0.46833086013793945
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  69
# time to fit:  21.75752544403076
# time to predict:  0.41829895973205566
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  70
# time to fit:  21.688449382781982
# time to predict:  0.4203009605407715
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  71
# time to fit:  21.735482931137085
# time to predict:  0.41930103302001953
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  72
# time to fit:  21.885586500167847
# time to predict:  0.4363114833831787
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  73
# time to fit:  21.840586185455322
# time to predict:  0.43628597259521484
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  74
# time to fit:  21.827551126480103
# time to predict:  0.4363107681274414
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  75
# time to fit:  21.95664072036743
# time to predict:  0.4212965965270996
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  76
# time to fit:  22.055711269378662
# time to predict:  0.42330217361450195
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  77
# time to fit:  21.871575355529785
# time to predict:  0.4283294677734375
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  78
# time to fit:  21.860599279403687
# time to predict:  0.4253265857696533
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  79
# time to fit:  21.818543672561646
# time to predict:  0.43930816650390625
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  80
# time to fit:  21.86657476425171
# time to predict:  0.49535155296325684
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  81
# time to fit:  21.740487575531006
# time to predict:  0.4212758541107178
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  82
# time to fit:  21.870604276657104
# time to predict:  0.43230581283569336
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  83
# time to fit:  21.757498502731323
# time to predict:  0.4283022880554199
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  84
# time to fit:  21.77751135826111
# time to predict:  0.4192969799041748
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  85
# time to fit:  21.874581575393677
# time to predict:  0.4343085289001465
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  86
# time to fit:  21.80753469467163
# time to predict:  0.4333062171936035
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  87
# time to fit:  21.771517992019653
# time to predict:  0.42029571533203125
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  88
# time to fit:  21.963646173477173
# time to predict:  0.43730711936950684
#
# training score:  0.818178446026
# crossval score:  0.819336682278
# Done ::  89
# total time  2006.1234731674194

# %% [markdown]
# 400, njob=-1
# training score:  1.0
# crossval score:  0.799803514688
# oob score:  0.978233216013
#
# 0    294387
# 1      9058
# Name: 0, dtype: int64
# 0    292421
# 1     11024
# Name: click, dtype: int64
#
# 600, njob=-1
# worse performance
#
# 470, 510 looks good to me
#
# d1,2 : nestimators
# d 5,6 :
# d 3, 4 ; min sample split

# %% [markdown]
# # MODEL 1

# %% [markdown]
# Imbalance treatment

# %%
# df_ones = train[train.click==1]
# df_zero = train[train.click==0]
# rows = np.random.choice(df_zero.index.values, 430000)
# print(df_ones.shape[0])
# new_df = df_ones.append(df_zero.loc[rows])
# print(new_df.shape[0])
# rows = np.random.choice(new_df.index.values, new_df.shape[0])
# new_df = new_df.loc[rows]
# X_train, X_test, y_train, y_test = train_test_split(new_df[cols_to_use], new_df['click'], test_size = 0.5, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
import time
t1 = time.time()
dict5 = {}
dict6 = {}
for i in [20]:#, 4, 5, 10, 20, 50, 60, 70, 80, 100, 300, 500]:
    
    print("Model with ", i, " n estimators")
    model_mod = RandomForestClassifier(n_estimators=470, min_samples_split=50,  verbose=1, oob_score=True, n_jobs=-1, random_state=42)#lets use the fucing cores
    start = time.time()
    model_mod.fit(new_df[cols_to_use], new_df['click'])
    print("time to fit: ", time.time()-start)
    start = time.time()
#     pred = model_mod.predict(X_test)
    print("time to predict: ", time.time()-start ,"\n")
    print("training score: ", roc_auc_score(y_train, model_mod.predict(X_train)))
#     print("crossval score: ", roc_auc_score(y_test, pred))
    print("oob score: ", model_mod.oob_score_)
#     dict3[i]=roc_auc_score(y_test, pred)
#     dict4[i]=model_mod.oob_score_
    print("Done :: ", i)
print("total time ", time.time()-t1)
# Out:
# Model with  20  n estimators
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 470 out of 470 | elapsed:  4.0min finished
# time to fit:  299.62747049331665
# time to predict:  0.0
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=12)]: Done 470 out of 470 | elapsed:    4.4s finished
# training score:  0.918312706297
# oob score:  0.929364126495
# Done ::  20
# total time  304.6990611553192

# %%
import operator
max(dict2.items(), key=operator.itemgetter(1))[0]
# Out:
# 500

# %%
max(dict1.items(), key=operator.itemgetter(1))[0]
# Out:
# 0.79949729157596672

# %%
dict1[500]
# Out:
# 0.79893991850948654

# %%
dict2[500]
# Out:
# 0.97786411990350774

# %%
max(dict3.items(), key=operator.itemgetter(1))[0]
# Out:
# 80

# %%
max(dict4.items(), key=operator.itemgetter(1))[0]
# Out:
# 4

# %%
max(dict5.items(), key=operator.itemgetter(1))[0]

# %%
max(dict6.items(), key=operator.itemgetter(1))[0]

# %%
pred = pd.DataFrame(pred)
print(pred[0].value_counts())
y_test = pd.Series(y_test)
print(y_test.value_counts())
# Out:
# 0    294463
# 1      8982
# Name: 0, dtype: int64
# 0    292444
# 1     11001
# Name: click, dtype: int64

# %%
model_mod.random_state
# Out:
# 42

# %%
model_mod.estimators_[0].random_state
# Out:
# 1608637542

# %%
a = test.columns

# %%
test = pd.read_csv("test_modded.csv")

# %%
pred = model_mod.predict_proba(test[cols_to_use])

# %%
pred = pd.DataFrame(pred)
pred.shape
# Out:
# (3706907, 2)

# %%
sub = pd.DataFrame({'ID':test['ID'], 'click':pred[1]})
sub.to_csv('smallData_gbm_1.csv', index=False)

# %%
train.loc[a].to_csv("small_train.csv")
